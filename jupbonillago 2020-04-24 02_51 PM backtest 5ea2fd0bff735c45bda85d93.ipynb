# %% [markdown]
# Run the cell below to create your tear sheet.

# %%
bt = get_backtest('5ea2fd0bff735c45bda85d93')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:01:19|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-08-29</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>55</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-3.114%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-13.684%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>4.635%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.66</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.15</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.66</td>
#     </tr>
#     <tr>
# ...
